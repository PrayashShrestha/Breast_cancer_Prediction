# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pylab as plts #resizing the plot size
# %matplotlib inline

# %%
data = pd.read_csv("Breast.data.csv")

# %%
data.head()
# Out:
#    Sample Code Number  Clump Thickness  Uniformility of cell size  \
# 0             1002945                5                          4
# 1             1015425                3                          1
# 2             1016277                6                          8
# 3             1017023                4                          1
# 4             1017122                8                         10
#
#    Uniformility of cell shape  Marginal Adhesion  Single Epithelial Cell  \
# 0                           4                  5                       7
# 1                           1                  1                       2
# 2                           8                  1                       3
# 3                           1                  3                       2
# 4                          10                  8                       7
#
#    Bare Nuclei  Bland chromation  Normal Nucleoli  Mitoses  Class
# 0           10                 3                2        1      0
# 1            2                 3                1        1      0
# 2            4                 3                7        1      0
# 3            1                 3                1        1      0
# 4           10                 9                7        1      1

# %%
df = pd.DataFrame()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Sample Code Number          698 non-null    int64
#  1   Clump Thickness             698 non-null    int64
#  2   Uniformility of cell size   698 non-null    int64
#  3   Uniformility of cell shape  698 non-null    int64
#  4   Marginal Adhesion           698 non-null    int64
#  5   Single Epithelial Cell      698 non-null    int64
#  6   Bare Nuclei                 698 non-null    int64
#  7   Bland chromation            698 non-null    int64
#  8   Normal Nucleoli             698 non-null    int64
#  9   Mitoses                     698 non-null    int64
#  10  Class                       698 non-null    int64
# dtypes: int64(11)
# memory usage: 60.1 KB

# %%
sns.histplot(data["Marginal Adhesion"], kde="true", stat="probability")
# Out:
# <AxesSubplot:xlabel='Marginal Adhesion', ylabel='Probability'>

# %% [markdown]
# ##HistPlot Result
# From the above hist plot with the KDE true in the normalized form of data it is made clear

# %%
sns.stripplot(x="Class", y="Normal Nucleoli",hue="Bare Nuclei", data=data, jitter=True)
plts.rcParams['figure.dpi'] = 100 #increasin the sizee of the plot

# %% [markdown]
# Here, we have got two classes either being benign or malingant on the basis of normal Nuclei. It resulted us with the data that showed us even the person with normal nucleoli can have higher chance of suffering from breast cancer.

# %%
sns.boxplot(x="Class", y="Normal Nucleoli",hue="Bare Nuclei", data=data)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Normal Nucleoli'>

# %%
sns.scatterplot(x="Uniformility of cell size", y="Uniformility of cell shape", data=data)
# Out:
# <AxesSubplot:xlabel='Uniformility of cell size', ylabel='Uniformility of cell shape'>

# %%
sns.pairplot(data, hue="Class",dropna=True)
